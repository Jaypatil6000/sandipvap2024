# %%
import pandas as pd

# %% [markdown]
# #### Series

# %%
s = pd.Series([56,77,33,12,66,83])

# %%
s
# Out:
# 0    56
# 1    77
# 2    33
# 3    12
# 4    66
# 5    83
# dtype: int64

# %%
s[4]
# Out:
# 66

# %%
s[2]
# Out:
# 33

# %%
s[2]=63

# %%
s
# Out:
# 0    56
# 1    77
# 2    63
# 3    12
# 4    66
# 5    83
# dtype: int64

# %%
s.size
# Out:
# 6

# %%
s.min()
# Out:
# 12

# %% [markdown]
# Data Frame

# %%
r =pd.Series([1,2,3,4,5])
n =pd.Series(['Ajay','Vijaya','Sameer','Priya','Pratap'])
m =pd.Series([67.88,78.34,72.86,83.26,57.88])

# %%
df=pd.DataFrame({
    'roll':r,
    'name':n,
    'marks':m
})
print(df)
# Out:
#    roll    name  marks
# 0     1    Ajay  67.88
# 1     2  Vijaya  78.34
# 2     3  Sameer  72.86
# 3     4   Priya  83.26
# 4     5  Pratap  57.88

# %%
df.shape
# Out:
# (5, 3)

# %%
df.size
# Out:
# 15

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# marks    float64
# dtype: object

# %% [markdown]
# # Read the datasets

# %%
df =pd.read_csv('student.csv')

# %%
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.head(3)
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19

# %%
df.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.iloc[4:,1:]
# Out:
#      name class  marks  age
# 4    asha    TE  63.28   20
# 5  ayesha    BE  49.55   20
# 6    amar    BE  65.34   19
# 7   amita    BE  68.33   23
# 8    amol    TE  56.75   20
# 9   anmol    BE  78.66   21

# %%
df.iloc[:,:]
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[4,1:4]
# Out:
# name      asha
# class       TE
# marks    63.28
# Name: 4, dtype: object

# %%
df.iloc[4,:4]
# Out:
# roll         5
# name      asha
# class       TE
# marks    63.28
# Name: 4, dtype: object

# %%
df.iloc[:,1]
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.iloc[[1,7,3,8],:]
# Out:
#    roll     name class  marks  age
# 1     2     amit    TE  59.77   21
# 7     8    amita    BE  68.33   23
# 3     4  ajinkya    TE  69.66   20
# 8     9     amol    TE  56.75   20

# %%
df.iloc[[3,5,6],[1,4]]
# Out:
#       name  age
# 3  ajinkya   20
# 5   ayesha   20
# 6     amar   19

# %%
df.iloc[4,3]
# Out:
# 63.28

# %%
df.loc[:,'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[:,['name','marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df[['name','marks','age']]
# Out:
#       name  marks  age
# 0     anil  56.77   22
# 1     amit  59.77   21
# 2   aniket  76.88   19
# 3  ajinkya  69.66   20
# 4     asha  63.28   20
# 5   ayesha  49.55   20
# 6     amar  65.34   19
# 7    amita  68.33   23
# 8     amol  56.75   20
# 9    anmol  78.66   21

# %%
df.name
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.drop(5)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop([5,7,8])
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 9    10    anmol    BE  78.66   21

# %%
df.drop('class',axis=1)
# Out:
#    roll     name  marks  age
# 0     1     anil  56.77   22
# 1     2     amit  59.77   21
# 2     3   aniket  76.88   19
# 3     4  ajinkya  69.66   20
# 4     5     asha  63.28   20
# 5     6   ayesha  49.55   20
# 6     7     amar  65.34   19
# 7     8    amita  68.33   23
# 8     9     amol  56.75   20
# 9    10    anmol  78.66   21

# %%
df.drop(['class','roll'],axis=1)
# Out:
#       name  marks  age
# 0     anil  56.77   22
# 1     amit  59.77   21
# 2   aniket  76.88   19
# 3  ajinkya  69.66   20
# 4     asha  63.28   20
# 5   ayesha  49.55   20
# 6     amar  65.34   19
# 7    amita  68.33   23
# 8     amol  56.75   20
# 9    anmol  78.66   21

# %% [markdown]
# # Data import methods

# %%
cols = ['A','B','C','D','E']
df1 = pd.read_csv('student1.csv',names=cols)

# %%
df1
# Out:
#     A        B   C      D   E
# 0   1     anil  TE  56.77  22
# 1   2     amit  TE  59.77  21
# 2   3   aniket  BE  76.88  19
# 3   4  ajinkya  TE  69.66  20
# 4   5     asha  TE  63.28  20
# 5   6   ayesha  BE  49.55  20
# 6   7     amar  BE  65.34  19
# 7   8    amita  BE  68.33  23
# 8   9     amol  TE  56.75  20
# 9  10    anmol  BE  78.66  21

# %%
df2 = pd.read_csv('student3.tsv')

# %% [markdown]
# ##

# %%
df2
# Out:
#   roll\tname\tclass\tmarks\tage
# 0        1\tanil\tTE\t56.77\t22
# 1        2\tamit\tTE\t59.77\t21
# 2      3\taniket\tBE\t76.88\t19
# 3     4\tajinkya\tTE\t69.66\t20
# 4        5\tasha\tTE\t63.28\t20
# 5      6\tayesha\tBE\t49.55\t20
# 6        7\tamar\tBE\t65.34\t19
# 7       8\tamita\tBE\t68.33\t23
# 8        9\tamol\tTE\t56.75\t20
# 9      10\tanmol\tBE\t78.66\t21

# %%
df2 = pd.read_csv('student3.tsv', sep='\t')

# %%
df2
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %% [markdown]
# #### Custom column operations

# %%
x = ['M','M','M','M','F','F','M','F','M','M']

# %%
df['gender'] = x

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0     1     anil    TE  56.77   22      M
# 1     2     amit    TE  59.77   21      M
# 2     3   aniket    BE  76.88   19      M
# 3     4  ajinkya    TE  69.66   20      M
# 4     5     asha    TE  63.28   20      F
# 5     6   ayesha    BE  49.55   20      F
# 6     7     amar    BE  65.34   19      M
# 7     8    amita    BE  68.33   23      F
# 8     9     amol    TE  56.75   20      M
# 9    10    anmol    BE  78.66   21      M

# %%
df['marks']=df['marks'] +0.5

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0     1     anil    TE  57.27   22      M
# 1     2     amit    TE  60.27   21      M
# 2     3   aniket    BE  77.38   19      M
# 3     4  ajinkya    TE  70.16   20      M
# 4     5     asha    TE  63.78   20      F
# 5     6   ayesha    BE  50.05   20      F
# 6     7     amar    BE  65.84   19      M
# 7     8    amita    BE  68.83   23      F
# 8     9     amol    TE  57.25   20      M
# 9    10    anmol    BE  79.16   21      M

# %%
df['cgpa']=df['marks']/10+0.37

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0     1     anil    TE  57.27   22      M  6.097
# 1     2     amit    TE  60.27   21      M  6.397
# 2     3   aniket    BE  77.38   19      M  8.108
# 3     4  ajinkya    TE  70.16   20      M  7.386
# 4     5     asha    TE  63.78   20      F  6.748
# 5     6   ayesha    BE  50.05   20      F  5.375
# 6     7     amar    BE  65.84   19      M  6.954
# 7     8    amita    BE  68.83   23      F  7.253
# 8     9     amol    TE  57.25   20      M  6.095
# 9    10    anmol    BE  79.16   21      M  8.286

# %%
df.T
# Out:
#             0      1       2        3      4       5      6      7      8  \
# roll        1      2       3        4      5       6      7      8      9
# name     anil   amit  aniket  ajinkya   asha  ayesha   amar  amita   amol
# class      TE     TE      BE       TE     TE      BE     BE     BE     TE
# marks   57.27  60.27   77.38    70.16  63.78   50.05  65.84  68.83  57.25
# age        22     21      19       20     20      20     19     23     20
# gender      M      M       M        M      F       F      M      F      M
# cgpa    6.097  6.397   8.108    7.386  6.748   5.375  6.954  7.253  6.095
#
#             9
# roll       10
# name    anmol
# class      BE
# marks   79.16
# age        21
# gender      M
# cgpa    8.286

# %% [markdown]
# # Connect

# %%
# Merge, Join, Concat, Append

# %%
ndf = pd.DataFrame({
    'roll': range(1,11),
    'gender': ['M','M','M','M','F','F','M','F','M','M'],
    'cgpa':df['marks'] /10+0.37
})

# %%
ndf
# Out:
#    roll gender   cgpa
# 0     1      M  6.097
# 1     2      M  6.397
# 2     3      M  8.108
# 3     4      M  7.386
# 4     5      F  6.748
# 5     6      F  5.375
# 6     7      M  6.954
# 7     8      F  7.253
# 8     9      M  6.095
# 9    10      M  8.286

# %%
x4 =pd.read_csv('student.csv')

# %%
x4.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
ndf.columns
# Out:
# Index(['roll', 'gender', 'cgpa'], dtype='object')

# %%
df.merge(ndf, on='roll')
# Out:
#    roll     name class  marks  age gender_x  cgpa_x gender_y  cgpa_y
# 0     1     anil    TE  57.27   22        M   6.097        M   6.097
# 1     2     amit    TE  60.27   21        M   6.397        M   6.397
# 2     3   aniket    BE  77.38   19        M   8.108        M   8.108
# 3     4  ajinkya    TE  70.16   20        M   7.386        M   7.386
# 4     5     asha    TE  63.78   20        F   6.748        F   6.748
# 5     6   ayesha    BE  50.05   20        F   5.375        F   5.375
# 6     7     amar    BE  65.84   19        M   6.954        M   6.954
# 7     8    amita    BE  68.83   23        F   7.253        F   7.253
# 8     9     amol    TE  57.25   20        M   6.095        M   6.095
# 9    10    anmol    BE  79.16   21        M   8.286        M   8.286

# %%
df5 = pd.read_csv('student5.csv')

# %%
df5
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df,df5])
# Out:
#    roll     name class  marks  age gender   cgpa
# 0     1     anil    TE  57.27   22      M  6.097
# 1     2     amit    TE  60.27   21      M  6.397
# 2     3   aniket    BE  77.38   19      M  8.108
# 3     4  ajinkya    TE  70.16   20      M  7.386
# 4     5     asha    TE  63.78   20      F  6.748
# 5     6   ayesha    BE  50.05   20      F  5.375
# 6     7     amar    BE  65.84   19      M  6.954
# 7     8    amita    BE  68.83   23      F  7.253
# 8     9     amol    TE  57.25   20      M  6.095
# 9    10    anmol    BE  79.16   21      M  8.286
# 0     1   surbhi    TE  67.44   23    NaN    NaN
# 1     2    sujay    TE  74.12   22    NaN    NaN
# 2     3  subhash    BE  82.44   21    NaN    NaN
# 3     4   sachin    TE  59.33   21    NaN    NaN
# 4     5  shalini    TE  63.45   20    NaN    NaN

# %%
pd.concat([df,df5], ignore_index=True)
# Out:
#     roll     name class  marks  age gender   cgpa
# 0      1     anil    TE  57.27   22      M  6.097
# 1      2     amit    TE  60.27   21      M  6.397
# 2      3   aniket    BE  77.38   19      M  8.108
# 3      4  ajinkya    TE  70.16   20      M  7.386
# 4      5     asha    TE  63.78   20      F  6.748
# 5      6   ayesha    BE  50.05   20      F  5.375
# 6      7     amar    BE  65.84   19      M  6.954
# 7      8    amita    BE  68.83   23      F  7.253
# 8      9     amol    TE  57.25   20      M  6.095
# 9     10    anmol    BE  79.16   21      M  8.286
# 10     1   surbhi    TE  67.44   23    NaN    NaN
# 11     2    sujay    TE  74.12   22    NaN    NaN
# 12     3  subhash    BE  82.44   21    NaN    NaN
# 13     4   sachin    TE  59.33   21    NaN    NaN
# 14     5  shalini    TE  63.45   20    NaN    NaN

# %% [markdown]
# # Methods pr Functions

# %%
df['marks'].mean()
# Out:
# 64.999

# %%
df['marks'].max()
# Out:
# 79.16

# %%
df['marks'].min()
# Out:
# 50.05

# %%
df['marks'].sum()
# Out:
# 649.9899999999999

# %%
df['marks'].median()
# Out:
# 64.81

# %%
df['marks'].std()
# Out:
# 9.207178901994535

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0     1     anil    TE  57.27   22      M  6.097
# 1     2     amit    TE  60.27   21      M  6.397
# 2     3   aniket    BE  77.38   19      M  8.108
# 3     4  ajinkya    TE  70.16   20      M  7.386
# 4     5     asha    TE  63.78   20      F  6.748
# 5     6   ayesha    BE  50.05   20      F  5.375
# 6     7     amar    BE  65.84   19      M  6.954
# 7     8    amita    BE  68.83   23      F  7.253
# 8     9     amol    TE  57.25   20      M  6.095
# 9    10    anmol    BE  79.16   21      M  8.286

# %%
df['class'].mode()
# Out:
# 0    BE
# 1    TE
# Name: class, dtype: object

# %%
df['age'].mode()
# Out:
# 0    20
# Name: age, dtype: int64

# %%
df['class'].value_counts()
# Out:
# TE    5
# BE    5
# Name: class, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 20    4
# 21    2
# 19    2
# 22    1
# 23    1
# Name: age, dtype: int64

# %%
df.sum()
# Out:
# roll                                                     55
# name      anilamitaniketajinkyaashaayeshaamaramitaamolanmol
# class                                  TETEBETETEBEBEBETEBE
# marks                                                649.99
# age                                                     205
# gender                                           MMMMFFMFMM
# cgpa                                                 68.699
# dtype: object

# %%
df.min()
# Out:
# roll            1
# name      ajinkya
# class          BE
# marks       50.05
# age            19
# gender          F
# cgpa        5.375
# dtype: object

# %%
df.mean()
# Out:
# C:\Users\jaypa\AppData\Local\Temp\ipykernel_14488\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# roll      5.5000
# marks    64.9990
# age      20.5000
# cgpa      6.8699
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
#  5   gender  10 non-null     object
#  6   cgpa    10 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 688.0+ bytes

# %%
df.describe()
# Out:
#            roll      marks        age       cgpa
# count  10.00000  10.000000  10.000000  10.000000
# mean    5.50000  64.999000  20.500000   6.869900
# std     3.02765   9.207179   1.269296   0.920718
# min     1.00000  50.050000  19.000000   5.375000
# 25%     3.25000  58.020000  20.000000   6.172000
# 50%     5.50000  64.810000  20.000000   6.851000
# 75%     7.75000  69.827500  21.000000   7.352750
# max    10.00000  79.160000  23.000000   8.286000

# %% [markdown]
# # String operations

# %%
df['name'].str.upper() # lower, title, swapcase
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.replace('i','ee')
# Out:
# 0       aneel
# 1       ameet
# 2     aneeket
# 3    ajeenkya
# 4        asha
# 5      ayesha
# 6        amar
# 7      ameeta
# 8        amol
# 9       anmol
# Name: name, dtype: object

# %%
df['name'].str.count('a')
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    2
# 5    2
# 6    2
# 7    2
# 8    1
# 9    1
# Name: name, dtype: int64

# %%
df['name'].str.startswith('an')
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: name, dtype: bool

# %%
df['name'].str.endswith('l')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: name, dtype: bool

# %% [markdown]
# # Grouping operations

# %%
gr=df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr.get_group('TE')
# Out:
#    roll     name class  marks  age gender   cgpa
# 0     1     anil    TE  57.27   22      M  6.097
# 1     2     amit    TE  60.27   21      M  6.397
# 3     4  ajinkya    TE  70.16   20      M  7.386
# 4     5     asha    TE  63.78   20      F  6.748
# 8     9     amol    TE  57.25   20      M  6.095

# %%
gr.agg(min)
# Out:
#        roll     name  marks  age gender   cgpa
# class
# BE        3     amar  50.05   19      F  5.375
# TE        1  ajinkya  57.25   20      F  6.095

# %% [markdown]
# # Boolean Filtering

# %%
df['marks']> 60
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
mask =df['marks']>60

# %%
df[mask]
# Out:
#    roll     name class  marks  age gender   cgpa
# 1     2     amit    TE  60.27   21      M  6.397
# 2     3   aniket    BE  77.38   19      M  8.108
# 3     4  ajinkya    TE  70.16   20      M  7.386
# 4     5     asha    TE  63.78   20      F  6.748
# 6     7     amar    BE  65.84   19      M  6.954
# 7     8    amita    BE  68.83   23      F  7.253
# 9    10    anmol    BE  79.16   21      M  8.286

# %%
df[df['marks']>60]
# Out:
#    roll     name class  marks  age gender   cgpa
# 1     2     amit    TE  60.27   21      M  6.397
# 2     3   aniket    BE  77.38   19      M  8.108
# 3     4  ajinkya    TE  70.16   20      M  7.386
# 4     5     asha    TE  63.78   20      F  6.748
# 6     7     amar    BE  65.84   19      M  6.954
# 7     8    amita    BE  68.83   23      F  7.253
# 9    10    anmol    BE  79.16   21      M  8.286

# %%
df[df['name'].str.startswith('an')]
# Out:
#    roll    name class  marks  age gender   cgpa
# 0     1    anil    TE  57.27   22      M  6.097
# 2     3  aniket    BE  77.38   19      M  8.108
# 9    10   anmol    BE  79.16   21      M  8.286

# %%
x =df[(df['marks']>60) & (df['class'] == 'BE')]

# %%
x
# Out:
#    roll    name class  marks  age gender   cgpa
# 2     3  aniket    BE  77.38   19      M  8.108
# 6     7    amar    BE  65.84   19      M  6.954
# 7     8   amita    BE  68.83   23      F  7.253
# 9    10   anmol    BE  79.16   21      M  8.286

# %% [markdown]
# # Export the data

# %%
x.to_csv('output.csv',index=False)

# %%
x.to_html('output.html', index = False)
