# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 10, 0.25)

# %%
x
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25,
#        5.5 , 5.75, 6.  , 6.25, 6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  ,
#        8.25, 8.5 , 8.75, 9.  , 9.25, 9.5 , 9.75])

# %%
y = x-4.5 +84.21

# %%
y
# Out:
# array([79.71, 79.96, 80.21, 80.46, 80.71, 80.96, 81.21, 81.46, 81.71,
#        81.96, 82.21, 82.46, 82.71, 82.96, 83.21, 83.46, 83.71, 83.96,
#        84.21, 84.46, 84.71, 84.96, 85.21, 85.46, 85.71, 85.96, 86.21,
#        86.46, 86.71, 86.96, 87.21, 87.46, 87.71, 87.96, 88.21, 88.46,
#        88.71, 88.96, 89.21, 89.46])

# %%
plt.plot(x, y)
